# %%
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_row', 500)
sns.set()
# %matplotlib inline
# %precision 6
# Out:
# '%.6f'

# %%
plt.rcParams['font.family'] = 'IPAexGothic'
plt.rcParams['font.size'] = 6

# %%
# 打席結果データの読み込み
bats = pd.read_csv('../live-stats/bat-2023.csv')

# %%
batter_id = 2000035

# %%
player = pd.DataFrame([])

# %%
player['AB'] = bats.groupby(['batter.name']).count()['batter.id'].sort_values(ascending=False)

# %%
player['RE'] = bats.groupby(['batter.name']).sum(numeric_only=True)['rc'].sort_values(ascending=False)

# %%
player.sort_values('RE', ascending=False)
# Out:
#              AB     RE
# batter.name
# 栗原 陵矢        22  6.652
# 近藤 健介        21  5.597
# ブリンソン        18  4.834
# 宮﨑 敏郎        20  4.342
# 森下 翔太        16  3.899
# 中田 翔         20  3.807
# 村上 宗隆        20  2.989
# 佐藤 輝明        20  2.953
# 小幡 竜平        18  2.784
# 中村 晃         20  2.336
# 牧原 大成        23  2.264
# 中野 拓夢        20  1.991
# 森 友哉         20  1.946
# 野村 佑希        21  1.850
# 大山 悠輔        20  1.633
# 鈴木 将平        12  1.578
# フランコ         22  1.563
# 岡本 和真        21  1.471
# 中川 圭太        21  1.449
# 秋山 翔吾        15  1.153
# 藤岡 裕大        12  1.140
# 愛斗           21  1.052
# 山口 航輝        20  1.027
# 大城 滉二         1  1.000
# 原口 文仁         2  0.963
# オスナ          20  0.917
# 藤原 恭大        16  0.809
# 戸柱 恭孝        11  0.723
# 山田 哲人        20  0.716
# 松本 剛         21  0.643
# 清水 優心         3  0.637
# 細川 成也         5  0.564
# 長野 久義         2  0.526
# 近本 光司        21  0.487
# 京田 陽太        11  0.460
# 柳 裕也          1  0.428
# 友杉 篤輝         5  0.386
# ビーディ          2  0.378
# ...

# %%
player['RE'].sum()
# Out:
# -71.977000
